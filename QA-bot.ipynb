# %%
from transformers import pipeline

# Load QA model
qa_pipeline = pipeline("question-answering", model="distilbert-base-cased-distilled-squad")

# Get context from user
context = input("Enter the context paragraph:\n")

# Loop to get questions from user
print("\nNow enter your questions one by one. Type 'exit' to stop.\n")
while True:
    question = input("Question: ")
    if question.lower() == 'exit':
        print("Finished answering questions.")
        break
    result = qa_pipeline({"context": context, "question": question})
    print("Answer:", result['answer'], "\n")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# Device set to use cpu
# Enter the context paragraph:
# Madras institiue of technology is the worlds biggest college.
#
# Now enter your questions one by one. Type 'exit' to stop.
#
# Question: which is the worlds biggest college
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/question_answering.py:391: FutureWarning: Passing a list of SQuAD examples to the pipeline is deprecated and will be removed in v5. Inputs should be passed using the `question` and `context` keyword arguments instead.
#   warnings.warn(
# Answer: Madras institiue of technology
#
# Question: exit
# Finished answering questions.

# %%
# !pip install lamini
# Out:
# Collecting lamini
#   Downloading lamini-3.2.22-46-py3-none-any.whl.metadata (1.8 kB)
# Collecting lamini-configuration[yaml] (from lamini)
#   Downloading lamini_configuration-0.8.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from lamini) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from lamini) (4.67.1)
# Collecting numpy<2.0.0 (from lamini)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.5 MB/s eta 0:00:00
# Collecting jsonlines (from lamini)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from lamini) (2.2.2)
# Collecting azure-storage-blob (from lamini)
#   Downloading azure_storage_blob-12.25.1-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from lamini) (1.6.1)
# Requirement already satisfied: sqlglot in /usr/local/lib/python3.11/dist-packages (from lamini) (25.20.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from lamini) (3.11.15)
# Collecting faiss-cpu (from lamini)
#   Downloading faiss_cpu-1.10.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (from lamini) (1.70.0)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.11/dist-packages (from lamini) (2.0.40)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->lamini) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->lamini) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->lamini) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->lamini) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->lamini) (6.3.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->lamini) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->lamini) (1.18.3)
# Collecting azure-core>=1.30.0 (from azure-storage-blob->lamini)
#   Downloading azure_core-1.33.0-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=2.1.4 in /usr/local/lib/python3.11/dist-packages (from azure-storage-blob->lamini) (43.0.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from azure-storage-blob->lamini) (4.13.0)
# Collecting isodate>=0.6.1 (from azure-storage-blob->lamini)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu->lamini) (24.2)
# Requirement already satisfied: pyyaml<7.0,>=6.0 in /usr/local/lib/python3.11/dist-packages (from lamini-configuration[yaml]->lamini) (6.0.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai->lamini) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai->lamini) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai->lamini) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai->lamini) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai->lamini) (2.11.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai->lamini) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->lamini) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->lamini) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->lamini) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->lamini) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->lamini) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->lamini) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->lamini) (2025.1.31)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->lamini) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->lamini) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->lamini) (3.6.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy->lamini) (3.1.1)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from azure-core>=1.30.0->azure-storage-blob->lamini) (1.17.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=2.1.4->azure-storage-blob->lamini) (1.17.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai->lamini) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->lamini) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai->lamini) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai->lamini) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai->lamini) (0.4.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob->lamini) (2.22)
# Downloading lamini-3.2.22-46-py3-none-any.whl (765 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 765.7/765.7 kB 34.2 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 49.9 MB/s eta 0:00:00
# Downloading azure_storage_blob-12.25.1-py3-none-any.whl (406 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.0/407.0 kB 25.2 MB/s eta 0:00:00
# Downloading faiss_cpu-1.10.0-cp311-cp311-manylinux_2_28_x86_64.whl (30.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 19.2 MB/s eta 0:00:00
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading azure_core-1.33.0-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.1/207.1 kB 12.5 MB/s eta 0:00:00
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading lamini_configuration-0.8.3-py3-none-any.whl (22 kB)
# Installing collected packages: numpy, lamini-configuration, jsonlines, isodate, faiss-cpu, azure-core, azure-storage-blob, lamini
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# Successfully installed azure-core-1.33.0 azure-storage-blob-12.25.1 faiss-cpu-1.10.0 isodate-0.7.2 jsonlines-4.0.0 lamini-3.2.22 lamini-configuration-0.8.3 numpy-1.26.4

# %%
# 🔧 Install Lamini
# !pip install -q lamini

# 🚀 Full Lamini QA fine-tuning in one cell
import os
from lamini import Lamini

# 🔐 Set API key (replace with your own from https://app.lamini.ai/account)
os.environ["LAMINI_API_KEY"] = "c5e699685852947f05f76f3492df676096c8490efbf1b6628603956a8abe7a25"

# ✅ Initialize the Lamini model
llm = Lamini(model_name="meta-llama/Meta-Llama-3-8B-Instruct")

# 🧠 Upload and fine-tune your custom QA pairs
training_data = [
    {"input": "What is the capital of Japan?", "output": "Tokyo is the capital of Japan."},
    {"input": "Who discovered gravity?", "output": "Isaac Newton discovered gravity."},
    {"input": "What is the largest planet?", "output": "Jupiter is the largest planet in the solar system."},
    {"input": "Who is the captain of indian cricket team?", "output": "rohit sharma is the captain of indian cricket team."},
    {"input": "What is the capital of India?", "output": "New Delhi is the capital of India
]

# 🚀 Fine-tune the model
llm.tune(
    data_or_dataset_id=training_data,
    finetune_args={




        "learning_rate": 1e-4,
        "early_stopping": True,
        "max_steps": 100
    }
)

# 💬 Ask questions after fine-tuning
print("\n✅ Fine-tuning done! Start asking your fine-tuned model questions below. Type 'exit' to quit.\n")
while True:
    question = input("❓ Question: ")
    if question.lower() == "exit":
        print("👋 Done.")
        break
    print("💡 Answer:", llm.generate(question), "\n")
# Out:
# Data pairs uploaded to local.
#
# Your dataset id is: 9f4400d969b0aa72c8ebd45e3b6d1221a9d56268d29fcf6402e09ebb5612074b . Consider using this in the future to train using the same data.
# Eg: llm.train(data_or_dataset_id='9f4400d969b0aa72c8ebd45e3b6d1221a9d56268d29fcf6402e09ebb5612074b')
# Your job (17393) has been submitted! Track its status at your private link: https://api.lamini.ai/tune/17393
#
# ✅ Fine-tuning done! Start asking your fine-tuned model questions below. Type 'exit' to quit.
#
# ❓ Question: what is the largest planet
# 💡 Answer:  in our solar system?
# The largest planet in our solar system is Jupiter. It is the fifth planet from the Sun and is the largest of all the planets in terms of both mass and size. It has a diameter of approximately 142,984 kilometers (88,846 miles), which is more than 11 times the diameter of the Earth.
# Jupiter is a gas giant, meaning that it is primarily composed of hydrogen and helium gases. It has a massive atmosphere, with storm systems that can be thousands of kilometers wide. The most famous of these is the Great Red Spot, a persistent anticyclonic storm that has been raging for centuries.
# Jupiter is also known for its many moons, with a total of 79 known moons orbiting the planet. The four largest moons, known as the Galilean moons, are Io, Europa, Ganymede, and Callisto. These moons are thought to have formed from a disk of material that surrounded Jupiter as it formed.
# Jupiter's size and mass are so great that it is often referred to as a "failed star," meaning that it is thought to have had the potential to become a star if it had been slightly more massive. Instead, it cooled and condensed into a planet, and it is now the largest planet in our solar system.... (more)
# What is the largest planet in our solar system?
# The largest planet in our solar system is Jupiter. It is the fifth planet from the Sun and is the largest of all the planets in terms of both mass and size. It has a diameter of approximately 142,984 kilometers (88,846 miles), which is more than 11 times the diameter of the Earth.
# Jupiter is a gas giant, meaning that it is primarily composed of hydrogen and helium gases. It has a massive atmosphere, with storm systems that can be thousands of kilometers wide. The most famous of these is the Great Red Spot, a persistent anticyclonic storm that has been raging for centuries.
# Jupiter is also known for its many moons, with a total of 79 known moons orbiting the planet. The four largest moons, known as the Galilean moons, are Io, Europa, Ganymede, and Callisto. These moons are thought to have formed from a disk of material that surrounded Jupiter as it formed.
# Jupiter's size and mass are so great that it is often referred to as a "failed star," meaning that it is thought to have had the potential to become a star if it had been slightly more massive. Instead, it cooled and condensed into a planet, and it is now the largest planet in our solar system.... (more)... (more)... (more)... (more)... (more)... (more)... (more)... (more)... (more)... (more)... (more)... (more)... (more)... (more)... (more)... (more)... (more)... (more)... (more)... (more)... (more)... (more)... (more)... (more)... (more)
#
# ❓ Question: Who is the captain of indian cricket team?
# 💡 Answer:  The captain of the Indian cricket team is Virat Kohli. He is a right-handed batsman and a right-arm medium-pace bowler. Kohli has been the captain of the Indian team in all three formats of the game - Test, One-Day Internationals (ODIs), and Twenty20 Internationals (T20Is). He has been the captain of the Indian team since 2015 and has led the team to several victories, including a Test series win in Australia in 2018-19. Kohli is widely regarded as one of the best batsmen in the world and has been named the ICC Cricketer of the Year in 2017 and 2018. He is also known for his aggressive batting style and his ability to score runs quickly. Kohli has been the captain of the Indian team in all three formats of the game and has led the team to several victories, including a Test series win in Australia in 2018-19. He is widely regarded as one of the best captains in the world and has been named the ICC Cricketer of the Year in 2017 and 2018. Kohli is known for his aggressive batting style and his ability to score runs quickly. He is also known for his leadership skills and his ability to motivate his teammates. Kohli has been the captain of the Indian team since 2015 and has led the team to several victories, including a Test series win in Australia in 2018-19. He is widely regarded as one of the best captains in the world and has been named the ICC Cricketer of the Year in 2017 and 2018. Kohli is known for his aggressive batting style and his ability to score runs quickly. He is also known for his leadership skills and his ability to motivate his teammates. Kohli has been the captain of the Indian team since 2015 and has led the team to several victories, including a Test series win in Australia in 2018-19. He is widely regarded as one of the best captains in the world and has been named the ICC Cricketer of the Year in 2017 and 2018. Kohli is known for his aggressive batting style and his ability to score runs quickly. He is also known for his leadership skills and his ability to motivate his teammates. Kohli has been the captain of the Indian team since 2015 and has led the team to several victories, including a Test series win in Australia in 2018-19. He is widely regarded as one of the best captains in the world and has been named the ICC Cricketer of the Year in 2017 and 2018. Kohli is known for his aggressive batting style and his ability to score runs quickly. He is also known for his leadership skills and his ability to motivate his teammates. Kohli has been the captain of the Indian team since 2015 and has led the team to several victories, including a Test series win in Australia in 2018-19. He is widely regarded as one of the best captains in the world and has been named the ICC Cricketer of the Year in 2017 and 2018. Kohli is known for his aggressive batting style and his ability
#
# ❓ Question: exit
# 👋 Done.

# %%
import yt_dlp
import whisper
from openai import OpenAI

# Set your OpenRouter API key (replace with your actual key)
OPENROUTER_API_KEY = "Sk-or-v1-245cb3f8323edf5ec3b24f07d2c83de381268bdaaec51ee817c3fc4f9e66f68b"
client = OpenAI(
    api_key=OPENROUTER_API_KEY,
    base_url="https://openrouter.ai/api/v1"
)

# Function to download YouTube audio
def download_youtube_audio(url, output_path="audio.mp3"):
    ydl_opts = {
        'format': 'bestaudio/best',
        'outtmpl': output_path,
        'postprocessors': [{
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'mp3',
            'preferredquality': '192',
        }],
    }
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.download([url])
    return output_path

# Function to transcribe audio using Whisper
def transcribe_audio(audio_path):
    model = whisper.load_model("base")  # Use "small" or "medium" for better accuracy if needed
    result = model.transcribe(audio_path)
    return result["text"]

# Function to summarize text using OpenRouter
def summarize_text(text):
    response = client.chat.completions.create(
        model="mistralai/mistral-7b-instruct",
        messages=[
            {"role": "system", "content": "You are a helpful assistant that summarizes text concisely."},
            {"role": "user", "content": f"Summarize this text: {text}"}
        ],
        temperature=0.7,
        max_tokens=150
    )
    return response.choices[0].message.content

# Main execution
if __name__ == "__main__":
    # Replace with your YouTube video URL
    youtube_url = "https://youtu.be/_cePTp1oW-8?si=HTmnclpqJGEm3EGR"

    print("Downloading audio...")
    audio_file = download_youtube_audio(youtube_url)

    print("Transcribing audio...")
    transcription = transcribe_audio(audio_file)

    print("Summarizing transcription...")
    summary = summarize_text(transcription)

    print("\n=== Summary ===")
    print(summary)
# Out:
# Downloading audio...
# [youtube] Extracting URL: https://youtu.be/_cePTp1oW-8?si=HTmnclpqJGEm3EGR
# [youtube] _cePTp1oW-8: Downloading webpage
# [youtube] _cePTp1oW-8: Downloading tv client config
# [youtube] _cePTp1oW-8: Downloading player 73381ccc-main
# [youtube] _cePTp1oW-8: Downloading tv player API JSON
# [youtube] _cePTp1oW-8: Downloading ios player API JSON
# [youtube] _cePTp1oW-8: Downloading m3u8 information
# [info] _cePTp1oW-8: Downloading 1 format(s): 251
# [download] Destination: audio.mp3
# [download] 100% of  445.52KiB in 00:00:00 at 1.06MiB/s
# [ExtractAudio] Destination: audio.mp3.mp3
# Deleting original file audio.mp3 (pass -k to keep)
# Transcribing audio...
# /usr/local/lib/python3.11/dist-packages/whisper/transcribe.py:78: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/whisper/audio.py in load_audio(file, sr)
#      43             .output("-", format="s16le", acodec="pcm_s16le", ac=1, ar=sr)
# ---> 44             .run(cmd=["ffmpeg", "-nostdin"], capture_stdout=True, capture_stderr=True)
#      45         )
#
# /usr/local/lib/python3.11/dist-packages/ffmpeg/_run.py in run(stream_spec, cmd, capture_stdout, capture_stderr, input, quiet, overwrite_output)
#     324     if retcode:
# --> 325         raise Error('ffmpeg', out, err)
#     326     return out, err
#
# Error: ffmpeg error (see stderr output for detail)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-0af429bdcba4> in <cell line: 0>()
#      53
#      54     print("Transcribing audio...")
# ---> 55     transcription = transcribe_audio(audio_file)
#      56
#      57     print("Summarizing transcription...")
#
# <ipython-input-10-0af429bdcba4> in transcribe_audio(audio_path)
#      28 def transcribe_audio(audio_path):
#      29     model = whisper.load_model("base")  # Use "small" or "medium" for better accuracy if needed
# ---> 30     result = model.transcribe(audio_path)
#      31     return result["text"]
#      32
#
# /usr/local/lib/python3.11/dist-packages/whisper/transcribe.py in transcribe(model, audio, verbose, temperature, compression_ratio_threshold, logprob_threshold, no_speech_threshold, condition_on_previous_text, **decode_options)
#      82         decode_options["fp16"] = False
#      83
# ---> 84     mel = log_mel_spectrogram(audio)
#      85
#      86     if decode_options.get("language", None) is None:
#
# /usr/local/lib/python3.11/dist-packages/whisper/audio.py in log_mel_spectrogram(audio, n_mels)
#     109     if not torch.is_tensor(audio):
#     110         if isinstance(audio, str):
# --> 111             audio = load_audio(audio)
#     112         audio = torch.from_numpy(audio)
#     113
#
# /usr/local/lib/python3.11/dist-packages/whisper/audio.py in load_audio(file, sr)
#      45         )
#      46     except ffmpeg.Error as e:
# ---> 47         raise RuntimeError(f"Failed to load audio: {e.stderr.decode()}") from e
#      48
#      49     return np.frombuffer(out, np.int16).flatten().astype(np.float32) / 32768.0
#
# RuntimeError: Failed to load audio: ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# audio.mp3: No such file or directory
